# %% [markdown]
# #Разметка корпуса и работа с ним
#
# На этом семинаре у нас две задачи:
#
# 1. Научиться делать морфологическую и синтаксическую разметку корпуса.
# 2. Научиться работать с ним: извлекать и обобщать информацию.
#
# [Ссылка](https://colab.research.google.com/drive/1yfcTR3D67kxCSC6IXIpJ0zWneovAFoAF?usp=sharing) на тетрадку в Google Colab.

# %%
# !pip install stanza
# Out:
# Requirement already satisfied: stanza in /usr/local/lib/python3.10/dist-packages (1.7.0)
# Requirement already satisfied: emoji in /usr/local/lib/python3.10/dist-packages (from stanza) (2.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from stanza) (1.25.2)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (3.20.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from stanza) (2.31.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from stanza) (3.2.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from stanza) (0.10.2)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (2.1.0+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stanza) (4.66.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3.0->stanza) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3.0->stanza) (1.3.0)

# %%
#Выполнение запросов в интернет — используем, чтобы скачать файл
import requests

#Работа с таблицами — понадобится, чтобы хранить наш корпус
import pandas as pd

#Выполнение быстрых математических вычислений — пригодится, потому что иначе
#корпус с большим количеством текстов может долго обрабатываться
import numpy as np

#Разметка морфологии и синтаксиса
import stanza

# %% [markdown]
# ##Разметка
#
# Будем использовать Stanza — см. [предыдущий конспект](https://colab.research.google.com/drive/1hyCIkszZY5dHAyCArhMWfQrdcdKFm-yW?usp=sharing).

# %%
#Скачиваем обученную для русского языка модель
stanza.download("ru")

#Загружаем модель
nlp = stanza.Pipeline(lang="ru", processors="tokenize, pos, lemma, depparse")
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.7.0.json:   0%|   …
# INFO:stanza:Downloading default packages for language: ru (Russian) ...
# INFO:stanza:File exists: /root/stanza_resources/ru/default.zip
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources.
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.7.0.json:   0%|   …
# INFO:stanza:Loading these models for language: ru (Russian):
# ==================================
# | Processor | Package            |
# ----------------------------------
# | tokenize  | syntagrus          |
# | pos       | syntagrus_charlm   |
# | lemma     | syntagrus_nocharlm |
# | depparse  | syntagrus_charlm   |
# ==================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!

# %% [markdown]
# ##Разметка длинного текста
#
# Как нам хранить информацию о длинном тексте? Наверное, будет не удобно размечать его каждый раз, когда он нам потребуется. Да и для поиска объект, который хранит Stanza, не самый удобный.
#
# Возможный вариант — преобразовать размеченный текст в таблицу, где в каждой строчке содержится информация об одном слове. Таким образом можно будет сохранить текст в файл — и в следующий раз не парсить текст заново, а только обратиться к уже размеченному файлу. Плюс для поиска и анализа даных в таблице есть удобный инструментарий.
#
# Для работы с таблицами будем использовать библиотеку Pandas.

# %%
#Скачиваем текстовый файл с книгой

response = requests.get('https://raw.githubusercontent.com/alekseyst/text_analysis_2024/main/Practical_6/alisa.txt')
aliсe_text = response.text

# %%
#Делим на абзацы
aliсe_split = aliсe_text.split('\r\n\r\n')

#Объединяем их в части, потому что иначе Google Colab скажет, что не хватает памяти:(

alice_split_batches = []
batch = ''

for paragrahp in aliсe_split:
  if len(batch) <= 50000:
    batch += '\r\n\r\n' + paragrahp
  else:
    alice_split_batches.append(batch)
    batch = paragrahp

if alice_split_batches[-1].endswith(batch[-100:]) == False:
  alice_split_batches.append(batch)

# %%
#Пройдёмся по каждому слову каждой из книги и добавим в новую табличку

#Создаём заголовок
cols = ['index', 'word', 'lemma', 'pos', 'feats',
        'synt', 'head']

#Создаём вспомогательный список
words = []

#Идём по нашим отрывкам текста
for paragrahp in alice_split_batches:

  #Пропускаем пустые строки
  if paragrahp == '':
    continue

  #Размечаем каждый абзац
  paragrahp_nlp = nlp(paragrahp)

  #Добавляем разметку во вспомогательный список
  for word_index, word in enumerate(paragrahp_nlp.iter_words()):
    words.append([word_index, word.text, word.lemma, word.upos, word.feats,
                  word.deprel, word.head])

aliсe_by_word = pd.DataFrame(words, columns = cols)

# %%
aliсe_by_word.head(15)
# Out:
#     index         word        lemma    pos  \
# 0       0        Льюис        Льюис  PROPN
# 1       1        Кэрро        Кэрро  PROPN
# 2       2            л         литр   NOUN
# 3       3            л         литр   NOUN
# 4       4  Приключения  приключение   NOUN
# 5       5        Алисы        Алиса  PROPN
# 6       6            в            в    ADP
# 7       7       стране       страна   NOUN
# 8       8        чудес         чудо   NOUN
# 9       9            –            –  PUNCT
# 10     10      Перевод      перевод   NOUN
# 11     11           Н.           Н.  PROPN
# 12     12           М.           М.  PROPN
# 13     13    Демуровой     Демурова  PROPN
# 14     14            –            –  PUNCT
#
#                                             feats       synt  head
# 0   Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing       root     0
# 1   Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing      appos     1
# 2   Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing       root     0
# 3   Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing       root     0
# 4   Animacy=Inan|Case=Nom|Gender=Neut|Number=Plur       root     0
# 5    Animacy=Anim|Case=Gen|Gender=Fem|Number=Sing       nmod     1
# 6                                            None       case     4
# 7    Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing       nmod     1
# 8   Animacy=Inan|Case=Gen|Gender=Neut|Number=Plur       nmod     4
# 9                                            None      punct     2
# 10  Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing       root     0
# 11  Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing       nmod     2
# 12  Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing  flat:name     3
# 13   Animacy=Anim|Case=Gen|Gender=Fem|Number=Sing  flat:name     3
# 14                                           None      punct     2

# %%
aliсe_by_word.to_csv('alice_corpus_words.tsv', sep = '\t', encoding='utf-8',  index = False)

# %%
alice_link = 'https://raw.githubusercontent.com/alekseyst/text_analysis_2024/main/Seminar_6/alice_corpus_words.tsv'

alice_by_word = pd.read_csv(alice_link, sep='\t')

# %% [markdown]
# ## Более сложная структура корпуса
#
# Конечно, мы можем работать с корпусом, который состоит больше, чем из одной книги. Его структура может быть разной в зависимости от ваших данных.
#
# Может быть нужно хранить мета-информацию о текстах, разметка по словам, гипотетически может быть разметка на уровне предложений. Всю эту информацию имеет смысл не смешивать, а хранить в отдельных табличках (при этом мы фактически создаём реляционную базу данных).
#
# Чтобы понимать, как таблички соотносятся друг с другом, нужны индексы.
#
# Создадим корпус, который содержит новости, скачанные со страницы Панорамы.
#
# Будем работать с готовой таблицей, в которой содержится метаинформация (при небольшом количестве элементов она может быть создана вручную, при большом — автоматически), и с ещё одной таблицей, в которой будет разметка для каждого слова.

# %%
#Считываем из файла табличку с метаинформацией о каждом файле (включая текст новости)

panorama_corpus_link = 'https://raw.githubusercontent.com/alekseyst/text_analysis_2023/main/Seminar_5/panorama_corpus.tsv'

panorama_corpus = pd.read_csv(panorama_corpus_link, sep='\t')

# %%
#panorama_corpus.head()
# Out:
#    index      date    sphere  \
# 0      0  4-3-2023  Общество
# 1      1  4-3-2023  Политика
# 2      2  4-3-2023  Политика
# 3      3  4-3-2023  Политика
# 4      4  3-3-2023  Общество
#
#                                                title  \
# 0  Гражданам разрешили добывать нефть и газ на св...
# 1  Китай подал заявку на вступление в Союзное гос...
# 2  Деколонизаторки из Франции потребовали вернуть...
# 3  Победа России: Госдума пересмотрела результаты...
# 4        Бездетных россиян будут ежегодно штрафовать
#
#                                                 text  \
# 0  Государственная дума приняла в третьем чтении ...
# 1  Заведующий Канцелярией Комиссии ЦК КПК по инос...
# 2  Активисты движения «Смерть колониализму» из Па...
# 3  Государственная дума приняла постановление «Об...
# 4  Государственная дума приняла в первом чтении з...
#
#                                                 link
# 0  https://panorama.pub/news/grazdanam-razresili-...
# 1  https://panorama.pub/news/kitaj-podal-zaavku-n...
# 2  https://panorama.pub/news/dekolonizatorki-iz-f...
# 3  https://panorama.pub/news/gosduma-peresmotrela...
# 4  https://panorama.pub/news/bezdetnyh-rossian-pr...

# %%
#Возьмём для скорости поменьше новостей

panorama_corpus = panorama_corpus.iloc[:50]

# %%
#Пройдёмся по каждому слову каждой из новостей и добавим в новую табличку
cols = ['index', 'text_index', 'word', 'lemma', 'pos', 'feats',
        'synt',  'head']
words = []

for word_index, word in enumerate(paragrahp_nlp.iter_words()):
  words.append([word_index, word.text, word.lemma, word.upos, word.feats,
                word.deprel, word.head])

for text_index, row in enumerate(panorama_corpus['text']):
  news_nlp = nlp(row)
  for word_index, word in enumerate(news_nlp.iter_words()):
    words.append([word_index, text_index, word.text, word.lemma, word.upos,
                  word.feats, word.deprel, word.head])

panorama_by_word = pd.DataFrame(words, columns = cols)

# %%
panorama_by_word.head()
# Out:
#    index text_index   word  lemma  \
# 0      0         Ах     ах   INTJ
# 1      1          ,      ,  PUNCT
# 2      2       дело   дело   NOUN
# 3      3         не     не   PART
# 4      4      шутка  шутка   NOUN
#
#                                              pos      feats synt  head
# 0                                           None  discourse    5   NaN
# 1                                           None      punct    1   NaN
# 2  Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing      nsubj    5   NaN
# 3                                           None     advmod    5   NaN
# 4   Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing       root    0   NaN

# %%
panorama_by_word.to_csv('panorama_corpus_words.tsv', sep = '\t', encoding='utf-8',  index = False)

# %%
panorama_by_word_link = 'https://raw.githubusercontent.com/alekseyst/text_analysis_2024/main/Seminar_6/panorama_corpus_words.tsv'

panorama_by_word = pd.read_csv(alice_link, sep='\t')

# %% [markdown]
# ##Работа с таблицами с помощью Pandas
#
# С полученной таблицей можно сделать очень много всего: извлечь любые данные, аггрегировать, представить в виде, удобном для построения графиков или статистического анализа.

# %%
#Ищем по любой колонке — например, по лемме

aliсe_by_word[aliсe_by_word['lemma'] == 'день'].head(15)
# Out:
#        index  word lemma   pos                                          feats  \
# 74        74  день  день  NOUN  Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing
# 214      214  дней  день  NOUN  Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur
# 1608    1608  день  день  NOUN  Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing
# 2986    2986  день  день  NOUN  Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
# 9270    9270  день  день  NOUN  Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing
# 10712    273  день  день  NOUN  Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
# 10873    434  день  день  NOUN  Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing
# 11890   1451  день  день  NOUN  Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
# 11892   1453  днем  день  NOUN  Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing
# 12406   1967  днем  день  NOUN  Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing
# 14554   4115   дня  день  NOUN  Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
# 19736   9297   дни  день  NOUN  Animacy=Inan|Case=Acc|Gender=Masc|Number=Plur
# 20738  10299  день  день  NOUN  Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing
# 20833  10394  день  день  NOUN  Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing
# 20842  10403  день  день  NOUN  Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing
#
#            synt  head
# 74          obl    20
# 214        nmod     3
# 1608        obl     8
# 2986      nsubj     5
# 9270       nmod     2
# 10712     nsubj    10
# 10873       obl    21
# 11890      conj     5
# 11892      nmod    12
# 12406       obl     8
# 14554       obl     1
# 19736       obl    10
# 20738  obl:tmod     6
# 20833       obl     7
# 20842       obl     3

# %%
#Ищем по больше, чем одному параметру

aliсe_by_word[(aliсe_by_word['lemma'] == 'день') & (aliсe_by_word['synt'] == 'nsubj')]
# Out:
#        index  word lemma   pos                                          feats  \
# 2986    2986  день  день  NOUN  Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
# 10712    273  день  день  NOUN  Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
# 28497   7536  день  день  NOUN  Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
#
#         synt  head
# 2986   nsubj     5
# 10712  nsubj    10
# 28497  nsubj    98

# %%
#Создаём частотный список для столбца
#.groupby() группирует таблицу по значением одного из столбцов, собирает вместе
#После этого со сгруппированными значениями можно что-то сделать: посчитать,
#сложить, найти среднее и т. д. Методы .size() и .count() — считают элементы

aliсe_by_word.groupby('lemma').size().nlargest(15)
# Out:
# lemma
# ,        3531
# –        2104
# .        2081
# и        1008
# в         831
# "         726
# не        664
# она       637
# !         619
# Алиса     511
# я         484
# что       478
# на        390
# :         367
# быть      357
# dtype: int64

# %% [markdown]
# # Задание
#
# Посчитайте количество лемм так, чтобы среди них не учитывались пунктуационные знаки.

# %%
#Впишите сюда свой код

# %%
# Можно искать по подстроке, а не по полному совпадению

aliсe_by_word[(aliсe_by_word['lemma'] == 'день') &
              (aliсe_by_word['feats'].str.contains('Number=Plur'))]
# Out:
#        index  word lemma   pos                                          feats  \
# 214      214  дней  день  NOUN  Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur
# 19736   9297   дни  день  NOUN  Animacy=Inan|Case=Acc|Gender=Masc|Number=Plur
# 27827   6866   дни  день  NOUN  Animacy=Inan|Case=Acc|Gender=Masc|Number=Plur
# 28624   7663   дни  день  NOUN  Animacy=Inan|Case=Acc|Gender=Masc|Number=Plur
# 29067   8106   дни  день  NOUN  Animacy=Inan|Case=Acc|Gender=Masc|Number=Plur
# 31628    596   дни  день  NOUN  Animacy=Inan|Case=Acc|Gender=Masc|Number=Plur
# 33226   2194   дни  день  NOUN  Animacy=Inan|Case=Acc|Gender=Masc|Number=Plur
# 34711   3679   дни  день  NOUN  Animacy=Inan|Case=Acc|Gender=Masc|Number=Plur
# 39664   8632   дни  день  NOUN  Animacy=Inan|Case=Acc|Gender=Masc|Number=Plur
#
#        synt  head
# 214    nmod     3
# 19736   obl    10
# 27827  conj    25
# 28624   obl    21
# 29067  nmod    27
# 31628   obl     8
# 33226   obl     7
# 34711   obl    14
# 39664   obl     3

# %%
#Более продвинутый уровень — к какому-то из столбцов можно применить функцию
#Например, посчитать количество символов для каждого из текстов, который у нас есть

panorama_corpus['len_text'] = panorama_corpus['text'].map(len)

#Можем выбрать этот столбец, чтобы посмотреть на него
panorama_corpus.loc[:, 'len_text'].head(15)
# Out:
# 0      991
# 1     1392
# 2     1673
# 3      776
# 4     1497
# 5     1505
# 6      986
# 7     1306
# 8      899
# 9     1190
# 10     887
# 11    1107
# 12    1676
# 13    1445
# 14     964
# Name: len_text, dtype: int64

# %%
#Численный параметр можно аггрегировать и посчитать для неё необходимую метрику
#Например, среднее:

panorama_corpus.aggregate('len_text').mean()
# Out:
# 1188.632

# %%
#Медиану

panorama_corpus.aggregate('len_text').median()
# Out:
# 1143.0

# %%
#Дисперсию, и так далее

panorama_corpus.aggregate('len_text').var()
# Out:
# 103072.6432051282

# %%
#Если нужно использовать информацию сразу из двух таблиц, их можно объединить
#Только не целиком — иначе получится слишком огромная таблица, которая потратит
#Все наши ресурсы!

#Получим таблицу, которая содержит дату создания примера для каждого слова.
#Объединять будем по индексу текста

panorama_by_word = panorama_by_word.join(
    panorama_corpus.loc[:, ['index', 'date']].set_index('index'),
    on='text_index')

panorama_by_word
# Out:
#         index  text_index             word            lemma    pos  \
# 0           0           0  Государственная  государственный    ADJ
# 1           1           0             дума             дума   NOUN
# 2           2           0          приняла          принять   VERB
# 3           3           0                в                в    ADP
# 4           4           0          третьем           третий    ADJ
# ...       ...         ...              ...              ...    ...
# 120287    154         624          ставить          ставить   VERB
# 120288    155         624           вопрос           вопрос   NOUN
# 120289    156         624         подобным         подобный    ADJ
# 120290    157         624          образом            образ   NOUN
# 120291    158         624                »                "  PUNCT
#
#                                                     morph synt_relation  \
# 0              Case=Nom|Degree=Pos|Gender=Fem|Number=Sing          amod
# 1            Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing         nsubj
# 2       Aspect=Perf|Gender=Fem|Mood=Ind|Number=Sing|Te...          ROOT
# 3                                                                  case
# 4             Case=Loc|Degree=Pos|Gender=Neut|Number=Sing          amod
# ...                                                   ...           ...
# 120287                  Aspect=Imp|VerbForm=Inf|Voice=Act         xcomp
# 120288      Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing           obj
# 120289        Case=Ins|Degree=Pos|Gender=Masc|Number=Sing          amod
# 120290      Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing           obl
# 120291                                                            punct
#
#            head        date
# 0          дума    4-3-2023
# 1       приняла    4-3-2023
# 2       приняла    4-3-2023
# 3        чтении    4-3-2023
# 4        чтении    4-3-2023
# ...         ...         ...
# 120287   вправе  25-11-2022
# 120288  ставить  25-11-2022
# 120289  образом  25-11-2022
# 120290  ставить  25-11-2022
# 120291    имеем  25-11-2022
#
# [120292 rows x 9 columns]
